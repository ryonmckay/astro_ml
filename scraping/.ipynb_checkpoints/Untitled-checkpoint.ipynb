# %%
import pandas as pd
import json

# Load data from the first JSON file 'people_10.json'
with open('../data/people/people_10.json', 'r') as f:
    data1 = json.load(f)
df1 = pd.read_json(json.dumps(data1))

# Load data from the second JSON file 'people_20.json'
with open('../data/people/people_20.json', 'r') as f:
    data2 = json.load(f)
df2 = pd.read_json(json.dumps(data2))

# Load data from the second JSON file 'people_20.json'
with open('../data/people/people_30.json', 'r') as f:
    data3 = json.load(f)
df3 = pd.read_json(json.dumps(data3))

# Load data from the second JSON file 'people_20.json'
with open('../data/people/people_40.json', 'r') as f:
    data4 = json.load(f)
df4 = pd.read_json(json.dumps(data4))

# Load data from the second JSON file 'people_20.json'
with open('../data/people/people_50.json', 'r') as f:
    data5 = json.load(f)
df5 = pd.read_json(json.dumps(data5))

# Load data from the second JSON file 'people_20.json'
with open('../data/people/people_60.json', 'r') as f:
    data6 = json.load(f)
df6 = pd.read_json(json.dumps(data6))

# Concatenate the two DataFrames into a single DataFrame
df = pd.concat([df1, df2, df3, df4, df5, df6])

# Print the resulting DataFrame
print(df.head())
# Out:
#                      name birth_day  birth_month birth_year birth_time mercury_sign  mercury_pos_degrees  mercury_pos_minutes mercury_house  mercury_retrograde   venus_sign  venus_pos_degrees  venus_pos_minutes venus_house  mars_sign  mars_pos_degrees  mars_pos_minutes mars_house  sun_sign  sun_pos_degrees  sun_pos_minutes sun_house moon_sign  moon_pos_degrees  moon_pos_minutes  moon_house jupiter_sign  jupiter_pos_degrees  jupiter_pos_minutes jupiter_house  saturn_sign  saturn_pos_degrees  saturn_pos_minutes saturn_house uranus_sign  uranus_pos_degrees  uranus_pos_minutes uranus_house neptune_sign  neptune_pos_degrees  neptune_pos_minutes neptune_house  neptune_retrograde   pluto_sign  pluto_pos_degrees  pluto_pos_minutes pluto_house house_AC_sign  house_AC_pos_degrees  house_AC_pos_minutes house_2_sign  house_2_pos_degrees  house_2_pos_minutes house_3_sign  house_3_pos_degrees  house_3_pos_minutes house_IC_sign  house_IC_pos_degrees  house_IC_pos_minutes house_5_sign  \
# 0       Gouverneur Morris        30          1.0       1752      01:44     Aquarius                  2.0                 51.0             3                 1.0  Sagittarius               23.0               58.0           2     Taurus               1.0              19.0          6  Aquarius              9.0             52.0         3       Leo               2.0              20.0         9.0       Gemini                  1.0                 33.0             7  Sagittarius                21.0                44.0            2    Aquarius                28.0                17.0            3          Leo                  0.0                 26.0             9                 1.0  Sagittarius                8.0               40.0           1       Scorpio                  21.0                   4.0  Sagittarius                 21.0                 16.0    Capricorn                 26.0                 32.0        Pisces                   3.0                   2.0        Aries
# 1  Adolfh Freiherr Knigge        16         10.0       1752      05:30        Libra                  6.0                 11.0            12                 NaN      Scorpio                8.0               57.0           2      Libra              14.0              39.0          1     Libra             23.0             13.0         1  Aquarius               2.0              15.0         4.0       Cancer                 15.0                 19.0             9  Sagittarius                20.0                35.0            3    Aquarius                29.0                41.0            5          Leo                  4.0                 11.0            10                 NaN  Sagittarius                7.0               21.0           2         Libra                  12.0                  21.0      Scorpio                  7.0                 30.0  Sagittarius                  9.0                  1.0     Capricorn                  16.0                  19.0     Aquarius
# 2     George Rogers Clark        19         11.0       1752       None  Sagittarius                  1.0                 30.0                               NaN  Sagittarius               21.0               54.0                Scorpio               7.0              43.0              Scorpio             27.0             51.0              Taurus               3.0              33.0         NaN       Cancer                 15.0                 17.0                Sagittarius                23.0                55.0                 Aquarius                29.0                32.0                       Leo                  4.0                 15.0                               1.0  Sagittarius                8.0               34.0                      None                   NaN                   NaN         None                  NaN                  NaN         None                  NaN                  NaN          None                   NaN                   NaN         None
# 3       Thomas Chatterton        20         11.0       1752      06:14  Sagittarius                  2.0                 21.0             1                 NaN  Sagittarius               22.0               35.0           2    Scorpio               8.0               6.0         12   Scorpio             28.0             24.0         1    Taurus              11.0              13.0         6.0       Cancer                 15.0                 15.0             8  Sagittarius                23.0                59.0            2    Aquarius                29.0                32.0            3          Leo                  4.0                 15.0             9                 1.0  Sagittarius                8.0               35.0           1       Scorpio                  14.0                  19.0  Sagittarius                 13.0                 42.0    Capricorn                 21.0                 26.0        Pisces                   1.0                  10.0        Aries
# 4          Solomon Drowne        11          3.0       1753      08:00       Pisces                 12.0                 55.0            11                 NaN       Taurus                6.0                6.0           1  Capricorn              26.0              57.0         10    Pisces             21.0              8.0        12    Gemini               6.0              43.0         2.0       Cancer                  5.0                 53.0             3    Capricorn                 5.0                14.0            9      Pisces                 4.0                22.0           11          Leo                  1.0                 46.0             4                 1.0  Sagittarius               11.0               32.0           8        Taurus                   3.0                   7.0       Gemini                  4.0                 50.0       Gemini                 27.0                 15.0        Cancer                  17.0                  53.0          Leo
#
#    house_5_pos_degrees  house_5_pos_minutes house_6_sign  house_6_pos_degrees  house_6_pos_minutes house_DC_sign  house_DC_pos_degrees  house_DC_pos_minutes house_8_sign  house_8_pos_degrees  house_8_pos_minutes house_9_sign  house_9_pos_degrees  house_9_pos_minutes house_MC_sign  house_MC_pos_degrees  house_MC_pos_minutes house_11_sign  house_11_pos_degrees  house_11_pos_minutes house_12_sign  house_12_pos_degrees  house_12_pos_minutes           death_cause death_day  death_month death_year    occupation gender  uranus_retrograde  jupiter_retrograde  pluto_retrograde  saturn_retrograde  venus_retrograde  mars_retrograde
# 0                  4.0                 49.0       Taurus                  0.0                 17.0        Taurus                  21.0                   4.0       Gemini                 21.0                 16.0       Cancer                 26.0                 32.0         Virgo                   3.0                   2.0         Libra                   4.0                  49.0       Scorpio                   0.0                  17.0                  None        11          NaN       1816    politician   Male                NaN                 NaN               NaN                NaN               NaN              NaN
# 1                 21.0                 43.0       Pisces                 20.0                 14.0         Aries                  12.0                  21.0       Taurus                  7.0                 30.0       Gemini                  9.0                  1.0        Cancer                  16.0                  19.0           Leo                  21.0                  43.0         Virgo                  20.0                  14.0                  None         5          NaN       1796        writer   Male                1.0                 NaN               NaN                NaN               NaN              NaN
# 2                  NaN                  NaN         None                  NaN                  NaN          None                   NaN                   NaN         None                  NaN                  NaN         None                  NaN                  NaN          None                   NaN                   NaN          None                   NaN                   NaN          None                   NaN                   NaN                Stroke         2          NaN       1818       general   Male                NaN                 1.0               NaN                NaN               NaN              NaN
# 3                  2.0                 58.0        Aries                 26.0                 25.0        Taurus                  14.0                  19.0       Gemini                 13.0                 42.0       Cancer                 21.0                 26.0         Virgo                   1.0                  10.0         Libra                   2.0                  58.0         Libra                  26.0                  25.0  Suicide by Poisoning         8          NaN       1770  writer, poet   Male                NaN                 1.0               NaN                NaN               NaN              NaN
# 4                 11.0                 31.0        Virgo                 14.0                 30.0       Scorpio                   3.0                   7.0  Sagittarius                  4.0                 50.0  Sagittarius                 27.0                 15.0     Capricorn                  17.0                  53.0      Aquarius                  11.0                  31.0        Pisces                  14.0                  30.0                  None         2          NaN       1834        doctor   Male                NaN                 NaN               NaN                NaN               NaN              NaN

# %%
# drop the 2 na entries
print(df["sun_sign"].unique())

count = df['sun_sign'].isna().sum()
print('Number of NaN values in "Sun Sign" column:', count)
# Out:
# ['Aquarius' 'Libra' 'Scorpio' 'Pisces' 'Aries' 'Taurus' 'Leo' 'Virgo'
#  'Sagittarius' 'Capricorn' 'Gemini' 'Cancer' nan]
# Number of NaN values in "Sun Sign" column: 4

# %%
df.dropna(subset=['sun_sign'], inplace=True)

# %%
print(df["sun_sign"].unique())
# Out:
# ['Aquarius' 'Libra' 'Scorpio' 'Pisces' 'Aries' 'Taurus' 'Leo' 'Virgo'
#  'Sagittarius' 'Capricorn' 'Gemini' 'Cancer']

# %%
import matplotlib.pyplot as plt

plt.xlabel('Sun Sign')
plt.ylabel('Count')
plt.title('Histogram of Sun Sign')

# Create a histogram of sun sign data
plt.hist(df['sun_sign'], bins=12, alpha=0.5)
# Out:
# (array([1108.,  928.,  896., 1115., 1076., 1020., 1003.,  910.,  921.,
#         1065.,  985.,  969.]),
#  array([ 0.        ,  0.91666667,  1.83333333,  2.75      ,  3.66666667,
#          4.58333333,  5.5       ,  6.41666667,  7.33333333,  8.25      ,
#          9.16666667, 10.08333333, 11.        ]),
#  <BarContainer object of 12 artists>)

# %%
count = df['birth_time'].isna().sum()
print('Number of NaN values in "birth time" column:', count)
# Out:
# Number of NaN values in "birth time" column: 6575

# %%
len(df)
# Out:
# 11996

# %%
df["occupation"].unique()
# Out:
# array(['politician', 'writer', 'general', 'writer, poet', 'doctor',
#        'entrepreneur, inventor, businessman, scientist', 'chemist',
#        'politician, scientist general, builder',
#        'priest, philologist, historian, writer', 'diplomat',
#        'King of France and Navarre', None, 'writer, journalist',
#        'French portrait painter', 'soldier',
#        'Queen consort of France and Navarre, last Queen of France',
#        'composer, pianist, organist, virtuoso', 'lawyer',
#        'writer, politician, journalist, philosopher', 'poet',
#        'singer, writer, actor, director',
#        'Grand Duke of Saxe-Weimar-Eisenach', 'sculptor',
#        'writer, painter, poet, author of The Marriage of Heaven and Hell',
#        '5th President of the United States',
#        'writer, founder of Czech journalism', 'actor',
#        'singer, actor, opera singer', 'politician, lawyer', 'architect',
#        '252nd Pope', 'composer, teacher, conductor', '253rd Pope',
#        'scriptwriter',
#        'Empress of the French, wife of Napoleon Bonaparte',
#        'writer, translator', 'writer, actor', 'inventor of photography',
#        'King of Sardinia, Duke of Savoy', '254th Pope',
#        'writer, actor, translator, poet', 'inventor',
#        '7th President of the United States', 'King of Naples', 'musician',
#        'scientist', '6th President of the United States', 'composer',
#        'priest', 'Czech and Hungarian king, Roman and Austrian Emperor',
#        'writer, diplomat', 'writer, priest, translator',
#        'poet, fabulist, playwright, satirist, translator',
#        'Emperor of the French, King of Italy, military and political leader, general',
#        'French naturalist and zoologist', 'naturalist, traveler',
#        'philosopher', 'artist', 'poet, novelist',
#        'writer, philosopher, poet', '9th President of the United States',
#        'French general, Grand Marshal of the Palace',
#        'politician, diplomat', 'painter', 'astrologer', 'journalist',
#        'Queen consort of Prussia, wife of King Frederick William III.',
#        "Napoleon's sister, Grand Duchess of Tuscany, Princess of Lucca and Piombino",
#        'mathematician, physicist', 'teacher',
#        'poet, lawyer, songwriter, composer, novelist',
#        'sister of Napoleon I, nymphomaniac',
#        'physician, inventor of the stethoscope',
#        'architect, painter, designer', 'physicist', 'composer, guitarist',
#        '8th President of the United States',
#        'writer, representative of critical realism and romanticism',
#        'writer, actor, director, translator',
#        'Venezuelan military and political leader', 'mathematician',
#        '12th President of the United States',
#        'lawyer, linguist, collector of legends and fairy tales',
#        'writer, poet, cook', 'geologist, founder of modern geology',
#        'collector of fairy tales, linguist',
#        'Princess of Leiningen, Duchess of Kent and Strathearn',
#        'physicist, chemist',
#        'composer, bandleader, pianist and conductor',
#        'scientist, painter, photographer',
#        'writer, soldier, teacher, poet',
#        'inventor of a shorthand writing system',
#        'novelist, historian, US Navy sailor',
#        '10th President of the United States',
#        'traveler, explorer, geographer, surveyor',
#        'French archaeologist and founder of Egyptology',
#        'British naval officer and colonial administrator',
#        '15th President of the United States',
#        'inventor of Morse code and the telegraph, sculptor, painter',
#        'writer, scientist, poet', 'writer, soldier, poet', '255th Pope',
#        'Emperor of Austria, President of the German Confederation, King of Hungary, Croatia, and Bohemia',
#        'writer, scientist, priest, poet',
#        'illegitimate son of Prince Augustus Frederick and Augusta Murray',
#        'writer, politician, lawyer',
#        '11th President of the United States',
#        'Emperor and Autocrat of All the Russias', 'singer',
#        'composer, writer', 'child of celebrity', 'president',
#        'politician, businessman', 'composer, opera singer', 'actress',
#        'literary critic, founder of Czech historiography, called "Father of the Nation"',
#        '13th President of the United States', 'activist',
#        'chemist, inventor, developer of vulcanized rubber',
#        'photographer', 'poet, founder of Estonian national literature',
#        '2nd President of The Church of Jesus Christ of Latter-day Saints',
#        'physicist, scientist', 'singer, writer, actor, opera singer',
#        'teacher, philosopher', 'writer, poet, novelist, dramatist',
#        'Private Secretary to the President',
#        '14th President of the United States', 'priest, philosopher',
#        'cook', 'director', 'diplomat, businessman', 'businessman',
#        'writer, journalist, poet', 'leader of the Cherokee Nation',
#        'writer, translator, poet', 'general, politician, nationalist',
#        'writer, politician', 'theologian',
#        'dramatist, writer, actor, director of Estates Theatre, author of the Czech national anthem',
#        'painter, sculptor, graphic artist',
#        'Emperor of the French, 1st President of France',
#        '17th President of the United States',
#        'educator, inventor of braille', 'writer, poet, literary critic',
#        '16th President of the United States',
#        "naturalist, geologist, inventor of Darwin's evolutionary theory",
#        'psychiatrist', 'composer, musician', '256th Pope', 'dancer',
#        'writer, politician, journalist', 'doctor, scientist, teacher',
#        'Prussian scientist, founder of the German Egyptology',
#        'Marshal of France', 'successor of French Emperor Napoleon I.',
#        'piano virtuoso, composer', 'writer, theologian',
#        "founder of the luxury home of Tiffany's", 'writer, poet, priest',
#        'novelist, theologian, philosopher', 'cartoonist',
#        'writer, painter, poet', 'astrologer, writer',
#        'revolutionary anarchist, founder of collectivist anarchism',
#        'Roman Catholic prelate, first Archbishop of Santa Fe, New Mexico',
#        'playwright, Russian writer, classic of Russian Romanticism',
#        'musical instrument designer, inventor of the saxophone',
#        'physician, physicist, one of the founders of thermodynamics',
#        'politician, statesman',
#        'mathematician, philosopher, inventor of Boolean algebra',
#        'mathematician, inventor of the machine programming',
#        'writer, painter', 'painter, sculptor',
#        'writer, politician, priest', 'writer, scriptwriter',
#        'watchmaker, inventor, co-inventor of bulb',
#        'philosopher, political journalist, communist', 'conductor',
#        'Queen of the United Kingdom, Empress of India', 'novelist',
#        "physicist, inventor of the gyroscope and Foucault's Pendulum",
#        'writer, founder of modern Czech prose',
#        'physicist, president of the Academy of Sciences',
#        'photographer, portrait photography pioneer, journalist, writer',
#        'political philosopher, economist, co-founder of Marxism',
#        'translator, poet, essayist, critic', 'hashion designer',
#        'businessman, archaeolog, excavator of the Troy',
#        'psychologist, scientist', 'model',
#        '18th President of the United States',
#        'co-founder and leader of Czech sport organization Sokol',
#        '19th President of the United States',
#        'French biologist, chemist, doctor', 'physicist, mathematician',
#        'physician, anatomist and anthropologist',
#        'chemist, entrepreneur, founder of company Bayer AG',
#        'French doctor, founder of Neurology and Psychiatry', 'designer',
#        'writer, journalist, priest, poet',
#        'Catholic writer, translator, philosopher',
#        'founder and 1st General of The Salvation Army',
#        'Apache leader, medicine man, shaman', 'organic chemist',
#        '21st President of the United States', 'composer, conductor',
#        'composer, musician, conductor', 'composer, singer',
#        'scientist, doctor, physiologist, chronophotographer',
#        'Emperor of Austria, King of Hungary and Croatia, King of Bohemia',
#        'Duke in Bavaria',
#        'psychic, philosopher, journalist, founder of the Theosophical Society',
#        'inventor, automotive pioneer',
#        '20th President of the United States', 'writer, mathematician',
#        'writer, mathematician, politician',
#        'composer, singer, opera singer, teacher', 'painter, artist',
#        '23rd President of the United States',
#        'inventor of dynamite, founder and benefactor of the Nobel Prize',
#        'German evolutionary biologist, author of germ plasm theory',
#        'Russian chemist, creator of the Periodic Table of Elements',
#        'biologist, naturalist, philosopher, physician',
#        'architect, designer, painter', 'French sculptor, architect',
#        '257th Pope', 'actor, composer', 'chemist who synthesised indigo',
#        'artist, sculptor', '22th and 24th President of the United States',
#        'French general and politician', 'entrepreneur, founder of Opel',
#        'Austrian customs officer, father of Adolf Hitler',
#        '5th President of the French Republic', 'scientist, photographer',
#        'wife of Richard Wagner, daughter of Franz Liszt',
#        'Empress of Austria, wife of Francis Joseph I, the victim of assassination',
#        'psychologist, philosopher', 'writer, journalist, translator',
#        'general, aircraft manufacturer, founder of the Zeppelin airship company',
#        'actor, director', 'psychologist', 'priest, missionary, monk',
#        'veterinarian, inventor of Dunlop tires', 'painter, photographer',
#        'writer, teacher, scientist, inventor and philosopher',
#        'psychiatrist, neurologist, co-founder of modern sexology',
#        'founder of Heineken beer brand',
#        'writer, author of stories about Winnetou and Old Shatterhand',
#        '25th President of the United States', 'architect, painter',
#        'writer, lawyer, poet', 'composer, teacher',
#        'automotive designer, co-founder od Mercedes-Benz',
#        'actress, teacher', 'musician, writer, priest',
#        'Princess Sophie of Saxony, Duchess in Bavaria',
#        'writer, journalist, priest', 'Catholic novelist, essayist, poet',
#        'inventor of the phonograph and the light bulb',
#        'inventor of the microphone and the first phone',
#        'journalist, publisher, initiator of the creation of Pulitzer Prize appreciation',
#        'inventor, electrical engineer, entrepreneur',
#        'writer, traveler, archduke, geographer',
#        'felon, robber, murderer',
#        '2nd President of Germany, military officer, statesman',
#        'writer, author of Dracula',
#        '6th President of the French Republic',
#        'writer, actor, scriptwriter',
#        'American farmer, bison hunter, guardian of the law, sheriff, miner',
#        'singer, opera singer', 'journalist, poet',
#        'politician, writer, lawyer',
#        "philosopher, Friedrich Nietzsche's friend",
#        'politician, journalist', 'conductor, composer', 'tennis player',
#        'astrologer, editor of Raphael Ephemerids',
#        'Italian General and Marshal of Italy, politician',
#        'historically the first lady of the Czechoslovakia, the wife of T. G. Masaryk',
#        'producer', 'French general and Marshal of France',
#        'journalist, politician', 'writer, journalist, translator, poet',
#        'director, actor', 'writer, painter, journalist', 'field Marshal',
#        'politician, teacher', 'athlete',
#        'physician, founder of Czech medical terminology',
#        'engineer, designer, builder, inventor',
#        'occultist, Mason, founder of the Hermetic Order of the Golden dawn',
#        'composer, scriptwriter', '258th Pope', 'Archduchess of Austria',
#        'doctor, psychiatrist, neurologist, founder of psychoanalysis',
#        'admiral, engineer, scientist, explorer',
#        'inventor, electrical engineer, mechanical engineer, physicist, futurist',
#        'rchduchess of Austria, Royal Princess of Hungary, Croatia and Bohemia',
#        'playwright',
#        'British builder, promoter of daylight saving British Summer Time',
#        '28th President of the United States', 'architect, photographer',
#        'physician, neurologist, psychiatrist, inventor',
#        'actor, director, scriptwriter', 'writer, actress',
#        'lawyer, leading member of the American Civil Liberties Union',
#        'doctor, parasitologist, one of the founders of modern epidemiology, Nobel Prize in 1902 for malaria research',
#        'architect, designer', '259th Pope',
#        'psychologist, inventor of the first usable intelligence test',
#        '27th President of the United States', 'King of Sweden',
#        'politician, activist', '2nd President of Austria',
#        'journalist, children of celebrity',
#        '26rd President of the United States, writer, scientist',
#        'Italian opera composer, important representative of verismo',
#        'writer, physicist, poet', 'writer, wife of Oscar Wilde',
#        'German Emperor, King of Prussia',
#        'engineer, aerospace engineer, inventor, industrialist',
#        'French officer, falsely accused and convicted of high treason',
#        'psychologist, teacher, philosopher',
#        'ophthalmologist, founder and creator of the language Esperanto',
#        'writer, actor, director, scriptwriter',
#        'writer, scriptwriter, journalist',
#        'chemist, discoverer of cell-free fermentation',
#        'wife of Giacomo Puccini', 'First Lady of the United States',
#        'Russian-German writer and psychologist',
#        'philosopher, artist, critic, founder of anthroposophy',
#        'architect, diplomat', 'composer, writer, painter, philosopher',
#        'astrologer, founder of the magazine Le Déterminisme Astral',
#        'wife of Austrian psychoanalyst Sigmund Freud',
#        'writer, journalist, photographer, poet',
#        'inventor, entrepreneur, founder of Robert Bosch GmbH',
#        'educator, physician, innovator, inventor of basketball',
#        'director, actor, one of the first filmmakers',
#        'director, scriptwriter',
#        'businessman, chairman and managing director of the White Star Line',
#        'baseball player',
#        'Chief of Staff of the Belgian Army during the First World War',
#        'Russian actor, businessman, theater director, founder of the Moscow Art Theatre',
#        'journalist, translator', 'actor, director, cameraman',
#        'founder of Ford', 'composer, singer, writer, poet',
#        'Archduke of Austria, victim of assassination',
#        'Crown Princess of Austria, Hungary and Bohemia',
#        'psychiatrist, physician, neuropathologist',
#        'writer, teacher, translator',
#        'director, cameraman, one of the first filmmakers',
#        'writer, teacher', 'French sculptor, printmaker',
#        'Grand Duchess Elisabeth of Russia', 'singer, actress',
#        'pharmacist, author of Scoville scale depending on the amount of capsaicin',
#        'astrologer, author', 'writer, mathematician, scientist',
#        'Prince Imperial, Archduke of Austria, father of Charles I of Austria',
#        'King of the United Kingdom UK and Indian emperor',
#        'soccer player, coach', 'model, artist',
#        'automotive pioneer, co-founder of Laurin & Klement (now Škoda Auto)',
#        '29th President of the United States', 'pilot', 'writer, priest',
#        'musician, composer', 'designer, artist', 'fashion designer',
#        'writer, journalist, diplomat, poet',
#        'Finnish nobleman, politician, diplomat, military leader',
#        'one of the most important American architects',
#        'doctor, scientist',
#        'physicist, chemist, Nobel Prize in Physics (1903)',
#        'architect, teacher', 'German serial killer, cannibal',
#        "Duchess, wife of Franz Ferdinand d'Este, the victim of assassination",
#        'director, cameraman', 'painter, designer',
#        'Archduchess and Princess', 'director, camerawoman',
#        'entrepreneur, engineer, founder of Olivetti & Co',
#        'writer, director, scriptwriter',
#        'designer, founder of the company Horch and Audi',
#        'composer, pianist',
#        'German chess grandmaster, mathematician, philosopher',
#        'Russian mystic, self-proclaimed holy man', 'French serial killer',
#        'architect, designer, teacher',
#        'Italian general, air power theorist - bombing in aerial warfare',
#        "composer, conductor, Richard Wagner's son and grandson of Franz Liszt",
#        'German Lutheran theologian, philosopher, comparative religionist',
#        'activist, spiritual leader, politician, philosopher',
#        'serial killer',
#        'doctor, psychotherapist, founder of the school of individual psychology',
#        'director, cameraman, scriptwriter', 'serial killer, cannibal',
#        'actor, cameraman',
#        'founder of modern pedagogy, philosopher, scientist',
#        'King of Denmark', 'poet, writer', '4th President of Austria',
#        'co-founder of Ossetic prose', 'designer, child of celebrity',
#        'actor, scriptwriter', 'writer, mathematician, philosopher',
#        'Princess of Hesse, the last Empress of Russia',
#        '30th President of the United States',
#        '3rd President of Czechoslovakia', 'King of Norway',
#        'engineer, inventor, writer',
#        'writer, doctor, politician, teacher',
#        'Catholic saint, virgin, mystic', 'singer, actor, dancer',
#        'significant aviation pioneer and designer', 'guvernor',
#        'master of escape, magician, illusionist, stunt flier',
#        'writer, actor, director',
#        'professor of medicine, member of the Nazi Party',
#        'astrologer, Kabbalist, writer',
#        '31st President of the United States', 'writer, artist, poet',
#        'painter, philosopher', '1st President of Israel',
#        'politician, prime minister, soldier',
#        'theologian, organist, philosopher, physician',
#        'woman considered as the longest living person, only verified person to live to 120 years or beyond',
#        'scientist, presenter, chef, cookbook author',
#        'doctor, psychotherapist, founder of analytical psychology',
#        'founder of Porsche',
#        'occultist, writer, chess player, astrologer', 'murderer',
#        'Serbian physicist, wife of Albert Einstein',
#        'writer, sailor, gold-digger, wanderer, adventurer',
#        'wife and helper of illusionist Harry Houdini', '260th Pope',
#        'eye doctor, activist',
#        'entrepreneur, founder and CEO of Bata Shoes company',
#        'oriental dancer, artist, courtesan, agent of Germany and France',
#        'poet, novelist, dramatist, theorist, founder of Futurism',
#        'Nazi architect', 'automotive pioneer, co-founder of Renault',
#        'German politician of the Nazi Party, Reich Minister',
#        'German physician, psychoanalyst', 'figure skater',
#        'politician, Oberstleutnant in Wehrmacht, Generalmajor in NVA',
#        '1st President of Italy, jurist, journalist, politician',
#        '35th Vice President of the United States',
#        'actor, director, teacher',
#        'designer, Founder of Jawa motorcycles',
#        'industrialist, automotive pioneer',
#        'Jewish philosopher of religion, translator',
#        'writer, doctor, journalist, teacher', 'writer, doctor',
#        'american writer, columnist, politician',
#        'politician, dictator, mass murderer',
#        'co-founder of the Chevrolet Motor Car Company',
#        'painter, writer, photographer, poet', 'architect, artist',
#        'theoretical physicist, philosopher, scientist',
#        'founder of the Czechoslovak Red Cross, the daughter of T. G. Masaryk',
#        'Czech strongman and Greco-Roman wrestler',
#        'German art historian, founder of Bildarchiv Foto Marburg',
#        'actress, director',
#        'surgeon, Dr. Bob - co-founder of AA (Alcoholics Anonymous)',
#        'cameraman', 'composer, writer, poet',
#        'actress, singer, prima donna',
#        'German physicist, discoverer of X-ray scattering',
#        'singer, actor', 'Swiss modern painter, printmaker, illustrator',
#        '7th President of the Spanish Republic',
#        'German painter, co-founder of art group Der Blaue Reiter',
#        'painter, child of celebrity',
#        'graphic artist, writer, astrologer, mother of Reinhold Ebertin',
#        'politician, General of the French army, astronomer',
#        'Queen of the Netherlands',
#        'engineer, founder of Bentley Motors Limited',
#        'doctor, politician, teacher',
#        'US soldier, five-star general, politician',
#        'priest, religious, journalist, teacher',
#        'businessman, fashion designer, founder of Gucci',
#        'religious thinker, scientist, geologist, member of the Society of Jesus',
#        'commander, statesman, founder and first president of the Republic of Turkey',
#        'German Cardinal of the Roman Catholic Church',
#        'biologist, pharmacologist, botanist, known for discovery of the enzyme lysozyme',
#        'racer', 'painter, sculptor, printmaker, ceramicist',
#        'entrepreneur, patient of C.G.Jung, co-founder of AA (Alcoholics Anonymous)',
#        '261st Pope', 'architect, journalist, teacher', 'camerawoman',
#        '32nd President of the United States', 'actor, singer',
#        '17th President of France', 'writer, journalist, artist',
#        'general, Minister of National Defence',
#        'actor, director, cameraman, scriptwriter',
#        'Italian painter, sculptor, art critic, theorist of Futurism',
#        'Catholic philosopher', 'writer, actress, scriptwriter',
#        'writer, director, journalist, poet',
#        'astrologer, founder of the School of Ram', 'doctor, philosopher',
#        '14th and 17th President of Brazil',
#        'writer, philosopher, translator, poet', 'scriptwriter, actor',
#        'writer, politician, activist, poet', 'economist',
#        'cartoonist, animator, sculptor, engineer, inventor',
#        'architect, writer, painter', 'conductor, musician',
#        'physical trainer, inventor of Pilates method of physical fitness',
#        'founder of the Japanese martial art of Aikido',
#        'ice hockey player',
#        'scientist, physicist, inventor of the bathyscaphe, twin brother of Jean Piccard',
#        'chemist, twin', 'President of the Federal Republic of Germany',
#        'actor, director, translator', 'commander of the Japanese Navy',
#        '33rd President of the United States',
#        '2nd & 4th President of Czechoslovakia', 'writer, artist',
#        '16th President of France',
#        'business magnate, founder of Mars, Inc. (chocolate candy)',
#        'politician, diplomat, activist', 'psychologist, psychiatrist',
#        'psychologist, astrologer',
#        'novelist, winner of the Nobel Prize for Literature',
#        'Nazi politician, publisher of the antisemitic Der Stürmer',
#        'philosopher, theologian',
#        'actress, dancer, film producer, screenwriter',
#        'wife of president Edvard Beneš',
#        'writer, actor, scriptwriter, artist',
#        'nuclear physicist and scientist',
#        'actor, founder of the Genoese Dialectal Theatre',
#        'writer, director, poet',
#        'physician, founder of child psychoanalysis',
#        'four-star general and commander of US Army',
#        'actress, scriptwriter', 'astrologer, police detective, medium',
#        'painter, sculptor, architect, artist', 'writer, doctor, poet',
#        'organist, composer, pedagogue', 'Swiss Protestant theologian',
#        'politician, diplomat, children of celebrity',
#        'artist, painter, active communist, husband of painter Frida Kahlo',
#        'German expressionist painter, member of the group Der Blaue Reiter',
#        'singer, actor, director, scriptwriter',
#        'athlete, Olympic gold medalist',
#        'experimental physicist, Nobel Prize winner',
#        'theoretical physicist, co-founder of quantum mechanics',
#        'scientist, inventor',
#        'Swiss architect, urban planner, theorist, painter',
#        'singer, actor, director',
#        'President of the First Slovak Republic',
#        'senior British Army officer, field Marshal',
#        'writer, painter, artist', 'soccer player', 'composer, actor',
#        'composer, actor, scriptwriter', 'composer, actor, director',
#        'composer, director', 'engineer, inventor of the first television',
#        'businessman, politician, founder of the supermarket Migros',
#        'astrologer, doctor', 'scriptwriter, director',
#        'King of Yugoslavia, King of Serbs, Croats, and Slovenes',
#        'actor, comedian, composer, writer, director',
#        'politician, dictator, Nazi mass murderer',
#        'politician, dictator, former prime minister, president of Portugal',
#        'actor, opera singer, director',
#        'co-founder of the Jewish Nili spy network',
#        'writer, journalist, photographer, philosopher, translator',
#        'architect, co-founder of the movement De Stijl',
#        'politician, diplomat, Old Bolshevik', 'victim of murder',
#        'lieutenant general, executed for Chichijima incident (cannibalism)',
#        'writer, designer, poet',
#        'Chief of the Operations Staff of the Armed Forces High Command (OKW)',
#        'Vietnamese Communist revolutionary leader, prime minister, 1st President of the Democratic Republic of Vietnam',
#        'Austrian painter and cartoonist, disciple of Gustav Klimt',
#        'architect, painter, teacher', 'architect, designer, artist',
#        '34th President of the United States, general',
#        'politician, journalist, philosopher',
#        'actor, singer, comedian, footballer, film director',
#        'politician, critic of Nazism, the father of executed Sophie and Hans Scholl',
#        'actress, director, scriptwriter', 'psychologist, sculptor',
#        'writer, director',
#        'catholic philosopher, canonized as a martyr and saint',
#        'the first wife of Ernest Hemingway',
#        'Canadian physician, co-discoverer of insulin',
#        'writer, linguist, literary historian',
#        'German anti-Nazi theologian, Lutheran pastor',
#        'director, designer, puppeteer, creator of Spejbl and Hurvínek',
#        'astrologer, writer, teacher', 'Swiss psychologist',
#        'German pilot known as The Red Baron',
#        '1st President of Yugoslavia',
#        'Empress of Austria, Queen of Hungary, Queen of Bohemia',
#        'Oberst-Gruppenführer (colonel group leader) in the Waffen-SS',
#        'German Nazi politician, co-founder of the NSDAP',
#        'writer, painter, translator, poet',
#        'Field Marshal in the Wehrmacht of Nazi Germany',
#        'writer, actor, director, journalist, teacher, translator',
#        'lawyer, Nazi, Austrian Federal Chancellor', 'Polish general',
#        'composer, actor, scriptwriter, conductor',
#        'geneticist, evolutionary biologist, founder of population genetics',
#        'composer, writer, scriptwriter',
#        'politician, military leader of the Nazi Party (NSDAP)',
#        'philosopher, ideologue of the Nazi Party',
#        'actor, writer, commander, US Army General', 'guitarist, teacher',
#        'diplomat, lawyer, CIA Director', 'director, designer',
#        'cameraman, scriptwriter', 'Emperor of Ethiopia',
#        'the first white child born in the Arctic, daughter of arctic explorer, Admiral Peary',
#        'teacher and master of martial art Wing Chun',
#        'actor, journalist, dancer, teacher',
#        'psychology professor, member of nonviolent anti-Nazi group White Rose',
#        'German Nazi judge', 'boxer',
#        'Brazilian Iyálorixá (mother-of-santo), daughter of Oxum',
#        'writer, diplomat, translator, poet', 'Nazi German politician',
#        'director, teacher, translator',
#        'Grand Duchess, daughter of William IV. Luxembourg and Marie Anne Portuguese',
#        'King of the United Kingdom, Emperor of India',
#        'psychologist, biologist, entomologist, zoologist',
#        'singer, actress, opera singer',
#        "Bosnian Serb political activist, murderer who assassinated Franz Ferdinand d'Este",
#        'national artist, photographer, musician, director, cameraman and co-founder of Academy of Performing Arts in Prague',
#        'Nazi', 'silent film actress', 'Swiss Nazi politician',
#        'Tsar of Bulgaria', 'hockey player', '44th President of Mexico',
#        'composer, actor, director, cameraman, scriptwriter',
#        'professional boxer', 'photographer, painter',
#        'journalist, the second wife of Ernest Hemingway',
#        'astrologer, author of Koch house system',
#        'actor, comedian, star of silent film, director',
#        'amateur singer, aunt of Jacqueline Kennedy, Big Edie from the movie Grey Gardens',
#        '29th and 40th President of Argentina',
#        'actor, Best Actor Oscar in 1937',
#        'actor, cameraman, scriptwriter',
#        'priest, the Chief Rabbi of Paris', 'astrologer, psychologist',
#        '7th President of Czechoslovakia',
#        'Bill W. - co-founder of AA (Alcoholics Anonymous)',
#        'psychoanalyst, daughter of Sigmund Freud',
#        'King of the United Kingdom',
#        'astrologer, physicist, experimenter', 'actor, dancer',
#        'writer, psychologist', 'writer, philosopher',
#        'astrologer, physicist',
#        'sponsor, intiator of establishing AA (Alcoholics Anonymous)',
#        'writer, doctor, scriptwriter', 'singer, actress, director',
#        'psychologist, scientist, philosopher',
#        'actress, model, photographer, activist',
#        'Czechoslovak army officer, member of the anti-Nazi resistance',
#        'Russian physicist, inventor of the musical instrument the theremin - etherphone',
#        'golfer', '4th President of Czechoslovakia',
#        'politician, Minister of Defence, Marshal', 'translator',
#        'poet, theologian, sailor, Orthodox monk', 'actor, stuntman',
#        'the second daughter of Tsar Nicholas II, the last monarch of Russia',
#        "wife of Siegfried Wagner, Adolf Hitler's girlfriend",
#        '262nd Pope',
#        'Nazi war criminal, politician, Reich Minister of Propaganda of Nazi Germany',
#        'entrepreneur, founder of Puma, brother of Adidas founder',
#        'Catholic mystic, stigmatic', 'writer, actor, director, teacher',
#        'musician, singer, actor, director, translator, conductor',
#        'sculptor, cartoonist', 'writer, physicist',
#        'poet, novelist, theologian, literary scholar, author of The Chronicles of Narnia',
#        'composer, singer, actor, conductor', 'motorcycle racer',
#        'composer, musician, actor, director', 'film producer, tycoon',
#        'actress, singer', 'journalist, novelist, writer',
#        'actor, teacher', 'F1 racing driver',
#        'composer, singer, actor, director', 'singer, writer, actor',
#        'writer, painter, photographer, artist, poet',
#        'writer, actor, painter, poet', 'actor, director, dancer',
#        'photographer, sculptor', 'writer, diplomat, poet',
#        'painter, writer, actor', 'writer, scriptwriter, poet',
#        'psychologist, humanistic philosopher and sociologist',
#        'composer, music director',
#        'journalist, senior German Nazi official',
#        'theoretical physicist, Nobel Prize in Physics',
#        'high-ranking member of the Nazi SS - Obergruppenführer',
#        'lawyer, Nazi', 'composer, singer, actress',
#        'abstract animator, filmmaker, painter, director',
#        'novelist, journalist, aviator',
#        'The Queen Mother, wife of George VI',
#        'policies, Nazi Reich leader of the SS, the Gestapo Chief',
#        'writer, politician, poet',
#        'entrepreneur, designer, founder of Adidas',
#        'scriptwriter, writer', 'writer, daughter of writer Jack London',
#        '9th and 12th President of Cuba',
#        'astrologer, author, school teacher, developer of Cosmobiology',
#        'quantum chemist, biochemist', 'Emperor of Japan',
#        'actor, director, scriptwriter, teacher, artist',
#        '1st President of Indonesia', 'swimmer',
#        'the youngest daughter of the last ruler of the Russian Empire, Tsar Nicholas II.',
#        'director, scriptwriter, teacher', 'Catholic philosopher, writer',
#        'musician, singer', 'Chinese Christian evangelist',
#        'painter, singer, actress, model',
#        'writer, translator, journalist', 'director, politician',
#        'King of the Belgians', 'wife of Nazis Joseph Goebbels',
#        'scientist, journalist',
#        'nuclear physicist, creator of quantum mechanics',
#        'politician, victim of judicial murder, symbol of resistance against totalitarianism',
#        'aviator, first solo transatlantic flight',
#        'constructivist architect, painter',
#        'Scottish Olympic Gold Medalist runner, Christian missionary',
#        'wrestler, Olympic Champion in Greco-Roman wrestling',
#        'composer, actor, director, scriptwriter',
#        'actor, child of celebrity',
#        'actress, director, camerawoman, scriptwriter',
#        'President of Togo', '21st President of Brazil',
#        'singer, actor, presenter',
#        "businessman, founder of McDonald's Corporation", 'wrestler',
#        'writer, actress, poet', 'Duke of Kent',
#        'architect, actor, director', 'writer, mathematician, poet',
#        'politician, journalist, translator',
#        'writer, director, journalist', 'writer, teacher, cook',
#        'gangster', 'writer, essayist, satirist, anticommunist',
#        '1st President of Tunisia', 'politician, journalist, activist',
#        'writer, photographer', 'Nazi lawyer, chief of the RSHA',
#        'writer, teacher, philosopher, poet', 'photographer, designer',
#        'jazz musician, bandleader, trombonist',
#        'German Nazi official, main architect of the Holocaust',
#        'composer, director, cameraman, scriptwriter',
#        'musician, writer, teacher',
#        'painter, sculptor, writer, actor, artist, film director',
#        'soccer player, goalkeeper',
#        'composer, writer, actor, director, poet', 'director, animator',
#        'teacher, cook', 'mathematician, child of celebrity',
#        'presenter, cook', 'architect, designer, sculptor',
#        'writer, politician, journalist, poet', 'translator, writer',
#        'actor, scriptwriter, singer', 'murderess',
#        'athlete, politician, president of the International Amateur Athletic Federation (IAAF)',
#        'actress, dancer', "Nazi architect, Hitler's minister",
#        'neurologist, psychiatrist, Holocaust survivor',
#        'Catholic writer and philosopher', 'basketball player',
#        'writer, actor, director, poet',
#        'singer, actor, opera singer, teacher',
#        'politician, diplomat, 2nd secretary-general of the UN',
#        'nun, mystic, declared a saint on April 30, 2000',
#        'actress, opera singer',
#        'director, aviator, founder and owner of Hughes Aircraft, one of the richest people in the 70s',
#        'doctor, chemist', 'writer, sculptor', 'racing driver',
#        'scientist, better known as "the father of LSD"',
#        'entrepreneur, billionaire', 'evangelical theologian',
#        "astrologer, C. G. Jung's daughter", 'Nazi war criminal',
#        'mathematician, philosopher',
#        'politician, journalist, businessman', 'mystic, occultist',
#        'singer, dancer', 'Queen consort of Italy',
#        'serial killer, cannibal, necrophiliac',
#        'writer, criminal, author of the novel Papillon',
#        'politician, President of the Soviet Union',
#        'general, lawyer, war criminal, SS officer',
#        'singer, actress, painter',
#        'cartoonist, author of The Adventures of Tintin',
#        'designer of jewelry for Tiffany & Co.'], dtype=object)

# %%
counts = df['occupation'].value_counts()

# Filter the results to exclude occupations with less than 10 counts
counts = counts[counts >= 50]

# Create a bar chart of the remaining occupations
counts.plot(kind='bar')

# Set axis labels and title
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Histogram of Occupation')

# Show the plot
plt.show()

# %%
df["death_cause"].unique()
# Out:
# array([None, 'Stroke', 'Suicide by Poisoning', 'Execution by Beheading',
#        'Execution by Hanging', 'Murder', 'Disease', 'War Casualties',
#        'Tuberculosis', 'Injury', 'Heart Attack',
#        'Victims of Assassination', 'Pneumonia', 'Syphilis',
#        'Execution by Gunshot', 'Cancer', 'Unclear cause',
#        'Murder by Gunshot', 'Heart Failure', 'Suicide',
#        'Suicide by Gunshot', 'Cirrhosis', 'Fever', 'Drowning',
#        'Multiple Sclerosis', 'Accident', 'Suicide by Hanging',
#        'Train Accident', 'Liver Failure', 'Kidney Failure',
#        "Alzheimer's Disease", 'Respiratory/Lung Failure', 'Brain Failure',
#        'Diabetes', 'Influenza', 'Aneurysm', 'Alcohol', 'Car Accident',
#        'Asthma', 'Casualties of World War I', 'Leukemia', 'Execution',
#        'Execution by Electric Chair', 'Aviation Accident',
#        'Drug Overdose', 'Pill Overdose', "Parkinson's disease",
#        'Stomach Failure', 'AIDS'], dtype=object)

# %%
# Drop rows where 'death_cause' is NaN
df2 = df.dropna(subset=["death_cause"])

# Count the occurrences of each cause of death
counts = df2["death_cause"].value_counts()

counts = counts[counts >= 20]
# Create a bar chart of the causes of death
counts.plot(kind='bar')

# Set axis labels and title
plt.xlabel('Death Cause')
plt.ylabel('Count')
plt.title('Histogram of Death Cause')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Filter the DataFrame to include only occupations with more than 10 occurrences
counts = df['death_cause'].value_counts()
counts = counts[counts > 20]
df2 = df[df['death_cause'].isin(counts.index)]

# Create a contingency table of 'sun_sign' and 'occupation'
table = pd.crosstab(df2["death_cause"], df2['sun_sign'])

# Create a heatmap of the correlation
sns.heatmap(table, annot=True, cmap='YlGnBu')

# Set axis labels and title
plt.xlabel('sun_sign')
plt.ylabel("house_AC_sign")
plt.title('Correlation Between death cause and sun sign')

# Show the plot
plt.show()

# %%
df.shape
# Out:
# (11996, 95)
